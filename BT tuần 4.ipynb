# %%
#W4A1_1
try:
    n = int(input("Nhập số số nguyên nhỏ hơn hoặc bằng 1000:"))
    tong = 0
    if n > 0:
        if n <= 1000:
            for x in range(1,n+1):
                tong +=x
            print(tong)
        else:
            print("Số đã nhập không nhỏ hơn hoặc bằng 1000")
    else:
        print("Hình như bạn đã nhập số nguyên âm")
except ValueError:
    print("Đây không phải số nguyên")
# Out:
# Nhập số số nguyên nhỏ hơn hoặc bằng 1000: -1
# Hình như bạn đã nhập số nguyên âm

# %%
#W4A1_2
n = int(input("Nhập số nguyên nhỏ hơn hoặc bằng 1000:"))
x = 0
while x

# %%
import math
n = int(input("Nhập một số nguyên dương:"))
if n > 0:
    if n >= 2:
        for x in range(2,n):
            if n % x != 0:
                continue
            else:
                print("Đây không phải số nguyên tố")
                break
            print("Đây là số nguyên tố")
    else:
        print("Đây không phải số nguyên tố")
else:
    print("Đây không phải số nguyên dương:")
# Out:
# Nhập một số nguyên dương: 5

# %%
#W4A2

# %%
#W4A3

# %%
#W4A4

# %%
#W4A5

# %%
#W4A6

# %%
#W4A7

# %%
#W4A8

# %%
#W4A11
try:
n = int(input("Nhập số nguyên dương n: "))
count = 0
if n < 0 or n < 10**6:
 for x in range(2, n+1, 2):
    if n % x ==0:
        count += 1
    else:
        count = count
else:
    print("Số", n, "không nhỏ hơn 10^6")
print("Số lượng ước là số chẵn của",n,":",count)
except ValueError:
print("Hinh nhu so ban nhap khong phai so nguyen!")
# Out:
# Nhập số nguyên dương n:  80
# Số lượng ước là số chẵn của 80 : 8

# %%
#W4A12
X = float(input("Số tiền gửi ngân hàng là: "))
N = int(input("Số tháng người ấy gửi:"))
for _ in range(1, N+1):
    X = X*(1 + 0.007)
print("Số tiền rút được là:",int(X))    #khác gì với 0f
# Out:
# Số tiền gửi ngân hàng là:  760.54
# Số tháng người ấy gửi: 5
# Số tiền rút được là: 787

# %%
#W4A13
a, b = map(int, input("Nhập vào hai số nguyên dương: ").split())
A = 0
B = 0
for x in range(1,n+1):
    if a % x ==0:
        A +=0
for x in range(1,n+1):
    if b % x ==0:
        B +=0
if A == B:
    print("True")
else:
    print("False")
# Out:
# Nhập vào hai số nguyên dương:  220 284
# True

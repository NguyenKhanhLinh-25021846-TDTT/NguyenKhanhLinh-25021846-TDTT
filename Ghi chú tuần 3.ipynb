# %%
import builtins as bt
print(help(int))
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
txt = "Hello\fWorld!"
print(txt)
# Out:
# HelloWorld!

# %%
#Cộng các chữ số trong 1 số
n = int(input("Nhập 1 số nguyên:"))

# %%
import builtins as bt
print(dir(bt))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'PythonFinalizationError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarni
# ...

# %% [markdown]
# Phép gán trong biểu thức điều kiện là :=

# %%
#hàm len() dùng để trả về độ dài (số phần tử)
print(len("Ca"))
# Out:
# 2

# %%
#Bài 3:
c = input("Nhập một kí tự:")
if(len(c)==1):
    if(c.isupper):    #lược bỏ = True
        c_lower = chr(ord(c)+32)
        print(c_lower)
    elif(c.islower):
        c_upper = chr(ord(c)-32)
        print(c_upper)
    else:
        print("Đây không phải là một kí tự Alphabet")
else:
    print("Đây không phải một kí tự duy nhất")
# Out:
# Nhập một kí tự: a
# 

# %% [markdown]
# Bài toán có nhiều trường hợp phải test tất cả các nhánh

# %% [markdown]
# Shift L :  hiện số dòng

# %%
import math
a, b, c = map(float, input("Nhập vào 3 cạnh của tam giác:").split())
if(a + b > c and a + c > b and b + c > a):
    p = 0,5*(a + b + c)
    S = p*(p-a)*(p-b)*(p-c)
    S = sqrt(S)
    print("Diện tích tam giác:",f'S:.1f')
else:
    print("Không phải 3 cạnh của tam giác")
# Out:
# Nhập vào 3 cạnh của tam giác: 3 4 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       3 if(a + b > c and a + c > b and b + c > a):
#       4     p = 0,5*(a + b + c)
# ----> 5     S = p*(p-a)*(p-b)*(p-c)
#       6     S = sqrt(S)
#       7     print("Diện tích tam giác:",f'S:.1f')
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'float'

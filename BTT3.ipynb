# %%
#W3A2
#sư dung tinh chat (A XOR B) XOR B = A
a,b = map(int,input().split())
a = a^b
b = a^b
a = a^b
print(a,b)
# Out:
#  5 6
# 6 5

# %%
#W3A3
n = int(input())
print(n & (n - 1) == 0)
# Out:
#  4
# True

# %%
#W3A4
m,n = map(float,input().split())
print(int(m//n))
# Out:
#  38.2 4.5
# 8

# %%
#W3A5
m,n = map(float,input().split())
if m % n == 0:
    print(m//n)
else: print(int(m//n + 1))
# Out:
#  38.2 4.5
# 9

# %%
#W3A6
x = int(input("Nhập số nguyên dương: "))
if x % 2 == 0:
    print("Even")
else: print("Odd")
# Out:
# Nhập số nguyên dương:  6
# Even

# %%
#W3A7
a,b = map(int,input("Nhập hai số nguyên: ").split())
if a < 0 and b < 0:
    print("Yes")
else: print("No")
# Out:
# Nhập hai số nguyên:  -2 4
# No

# %%
#W3A8
a,b = map(str,input("Nhập hai chuỗi: ").split())
if len(a) > len(b):
    print("True")
else: print("False")
# Out:
# Nhập hai chuỗi:  hallo bye
# True

# %%
#W3A9
a,b,c = map(int,input("Nhập 3 số nguyên dương: ").split())
if a + b > c and b + c > a and c + a > b:
    print("Yes")
else: print("No")

# %%
#W3A10
a,b,c,d = map(int,input("Nhập 4 số nguyên: ").split())
max = a
if b > a: max = b
if c > b: max = c
if d > c: max = d
print(max)
# Out:
# Nhập 4 số nguyên:  2 8 6 4
# 8

# %%
#W3A11
a,b,c = map(int,input("Nhập 3 cạnh tam giác: ").split())
if a + b <= c and b + c <= a and c + a <= b:
    print("Không phải tam giác")
else: 
    if a == b == c: print("Tam giác đều")
    elif a == b or b == c or c == a: print("Tam giác cân")
    else: print("Tam giác thường")
# Out:
# Nhập 3 cạnh tam giác:  3 3 3
# Tam giác đều

# %%
#W3A12
n = int(input("Nhập năm: "))
if n % 400 == 0:
    print("Yes")
elif n % 4 == 0 and n % 100 != 0:
    print("Yes")
else: print("No")
# Out:
# Nhập năm:  1999
# No

# %%
#W3A14
a,b = map(int,input().split())
if a == 0 and b == 0: print("Vô số nghiệm")
elif a == 0: print("Vô nghiệm")
else: print(f"{-b/a:.2f}")
# Out:
#  4 -2
# 0.50

# %%
#W3A15
a = float(input("Điểm trung bình: "))
if a >= 8.0:
    print("Giỏi")
elif a >= 6.5:
    print("Khá")
elif a >= 5.0:
    print("Trung bình")
elif a < 5.0:
    print("Yếu")
# Out:
# Điểm trung bình:  9.0
# Giỏi

# %%
#W3A16
n = float(input("Nhập vào một số thực: "))
print(int(n // 1))
if n == n // 1:
    print(int(n))
else: print(int(n // 1 + 1))
if n - n // 1 == 0 or n - n // 1 < 0.5:
    print(int(n))
else: print(int(n // 1 + 1))
# Out:
# Nhập vào một số thực:  5.6
# 5
# 6
# 6

# %%
#W3A17
a,b,c,d = map(int,input().split())
cb = b // a
if b % a == 0:
    if b*cb == c and c*cb == d:
        print("Yes")
    else: print("No")
else: print("No")
# Out:
#  1 2 4 8
# Yes
